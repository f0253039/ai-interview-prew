# %% [markdown]
# <a href="https://colab.research.google.com/github/f0253039/ai-interview-prew/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day1 - Python Basics
name = input("type your name: ")
print("Hello", name)
# Out:
# type your name: gg
# Hello gg
